# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import norm

# %%
df = pd.read_csv("D://Dataset//Global_Education - ADE.csv", encoding='latin-1')
df
# Out:
#     Countries and areas  Latitude    Longitude  OOSR_Pre0Primary_Age_Male  \
# 0           Afghanistan  33.939110   67.709953                          0
# 1               Albania  41.153332   20.168331                          4
# 2               Algeria  28.033886    1.659626                          0
# 3               Andorra  42.506285    1.521801                          0
# 4                Angola  11.202692   17.873887                         31
# ..                  ...        ...         ...                        ...
# 197           Venezuela   6.423750   66.589730                         14
# 198             Vietnam  14.058324  108.277199                          0
# 199               Yemen  15.552727   48.516388                         96
# 200              Zambia  13.133897   27.849332                          0
# 201            Zimbabwe  19.015438   29.154857                         60
#
#      OOSR_Pre0Primary_Age_Female  OOSR_Primary_Age_Male  \
# ...

# %%
df.head()
# Out:
#   Countries and areas  Latitude   Longitude  OOSR_Pre0Primary_Age_Male  \
# 0         Afghanistan  33.939110  67.709953                          0
# 1             Albania  41.153332  20.168331                          4
# 2             Algeria  28.033886   1.659626                          0
# 3             Andorra  42.506285   1.521801                          0
# 4              Angola  11.202692  17.873887                         31
#
#    OOSR_Pre0Primary_Age_Female  OOSR_Primary_Age_Male  \
# 0                            0                      0
# 1                            2                      6
# 2                            0                      0
# 3                            0                      0
# 4                           39                      0
#
#    OOSR_Primary_Age_Female  OOSR_Lower_Secondary_Age_Male  \
# 0                        0                              0
# 1                        3                              6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 29 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Countries and areas                      202 non-null    object
#  1   Latitude                                 202 non-null    float64
#  2   Longitude                                202 non-null    float64
#  3   OOSR_Pre0Primary_Age_Male                202 non-null    int64
#  4   OOSR_Pre0Primary_Age_Female              202 non-null    int64
#  5   OOSR_Primary_Age_Male                    202 non-null    int64
#  6   OOSR_Primary_Age_Female                  202 non-null    int64
#  7   OOSR_Lower_Secondary_Age_Male            202 non-null    int64
#  8   OOSR_Lower_Secondary_Age_Female          202 non-null    int64
#  9   OOSR_Upper_Secondary_Age_Male            202 non-null    int64
# ...

# %%
df.describe()
# Out:
#         Latitude    Longitude  OOSR_Pre0Primary_Age_Male  \
# count  202.000000  202.000000                 202.000000
# mean    25.081422   55.166928                  19.658416
# std     16.813639   45.976287                  25.007604
# min      0.023559    0.824782                   0.000000
# 25%     11.685062   18.665678                   0.000000
# 50%     21.207861   43.518091                   9.000000
# 75%     39.901792   77.684945                  31.000000
# max     64.963051  178.065032                  96.000000
#
#        OOSR_Pre0Primary_Age_Female  OOSR_Primary_Age_Male  \
# count                   202.000000             202.000000
# mean                     19.282178               5.282178
# std                      25.171147               9.396442
# min                       0.000000               0.000000
# 25%                       0.000000               0.000000
# 50%                       7.000000               1.000000
# ...

# %%
df.columns
# Out:
# Index(['Countries and areas', 'Latitude ', 'Longitude',
#        'OOSR_Pre0Primary_Age_Male', 'OOSR_Pre0Primary_Age_Female',
#        'OOSR_Primary_Age_Male', 'OOSR_Primary_Age_Female',
#        'OOSR_Lower_Secondary_Age_Male', 'OOSR_Lower_Secondary_Age_Female',
#        'OOSR_Upper_Secondary_Age_Male', 'OOSR_Upper_Secondary_Age_Female',
#        'Completion_Rate_Primary_Male', 'Completion_Rate_Primary_Female',
#        'Completion_Rate_Lower_Secondary_Male',
#        'Completion_Rate_Lower_Secondary_Female',
#        'Completion_Rate_Upper_Secondary_Male',
#        'Completion_Rate_Upper_Secondary_Female',
#        'Grade_2_3_Proficiency_Reading', 'Grade_2_3_Proficiency_Math',
#        'Primary_End_Proficiency_Reading', 'Primary_End_Proficiency_Math',
#        'Lower_Secondary_End_Proficiency_Reading',
#        'Lower_Secondary_End_Proficiency_Math',
#        'Youth_15_24_Literacy_Rate_Male', 'Youth_15_24_Literacy_Rate_Female',
# ...

# %% [markdown]
# ### Mengambil Kolom yang Bersifat Number

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# %%
numeric_columns
# Out:
# Index(['Latitude ', 'Longitude', 'OOSR_Pre0Primary_Age_Male',
#        'OOSR_Pre0Primary_Age_Female', 'OOSR_Primary_Age_Male',
#        'OOSR_Primary_Age_Female', 'OOSR_Lower_Secondary_Age_Male',
#        'OOSR_Lower_Secondary_Age_Female', 'OOSR_Upper_Secondary_Age_Male',
#        'OOSR_Upper_Secondary_Age_Female', 'Completion_Rate_Primary_Male',
#        'Completion_Rate_Primary_Female',
#        'Completion_Rate_Lower_Secondary_Male',
#        'Completion_Rate_Lower_Secondary_Female',
#        'Completion_Rate_Upper_Secondary_Male',
#        'Completion_Rate_Upper_Secondary_Female',
#        'Grade_2_3_Proficiency_Reading', 'Grade_2_3_Proficiency_Math',
#        'Primary_End_Proficiency_Reading', 'Primary_End_Proficiency_Math',
#        'Lower_Secondary_End_Proficiency_Reading',
#        'Lower_Secondary_End_Proficiency_Math',
#        'Youth_15_24_Literacy_Rate_Male', 'Youth_15_24_Literacy_Rate_Female',
#        'Birth_Rate', 'Gross_Primary_Education_Enrollment',
# ...

# %% [markdown]
# ### Mencari Pemusatan dan Penyebaran Data

# %%
def describe_manual(data, columns):
    results = []
    for col in columns:
        mean = data[col].mean()
        mode = data[col].mode()[0]
        median = data[col].median()
        variance = data[col].var()
        std_dev = data[col].std()
        q1 = data[col].quantile(0.25)
        q2 = data[col].quantile(0.50)
        q3 = data[col].quantile(0.75)
        range_val = data[col].max() - data[col].min()

        results.append({
            'Column': col,
            'Mean': mean,
            'Mode': mode,
            'Median': median,
            'Varians': variance,
            'Standard Deviation': std_dev,
            'Quartile 1': q1,
            'Quartile 2': q2,
            'Quartile 3': q3,
            'Range': range_val
        })

    return pd.DataFrame(results)

stats = describe_manual(df, numeric_columns)
stats
# Out:
#                                       Kolom       Mean     Modus      Median  \
# 0                                 Latitude   25.081422  0.023559   21.207861
# 1                                 Longitude  55.166928  0.824782   43.518091
# 2                 OOSR_Pre0Primary_Age_Male  19.658416  0.000000    9.000000
# 3               OOSR_Pre0Primary_Age_Female  19.282178  0.000000    7.000000
# 4                     OOSR_Primary_Age_Male   5.282178  0.000000    1.000000
# 5                   OOSR_Primary_Age_Female   5.569307  0.000000    1.000000
# 6             OOSR_Lower_Secondary_Age_Male   8.707921  0.000000    2.000000
# 7           OOSR_Lower_Secondary_Age_Female   8.831683  0.000000    2.000000
# 8             OOSR_Upper_Secondary_Age_Male  20.292079  0.000000   15.000000
# 9           OOSR_Upper_Secondary_Age_Female  19.975248  0.000000   12.000000
# 10             Completion_Rate_Primary_Male  41.722772  0.000000   37.500000
# ...

# %%
for kolom in numeric_columns:
    plt.figure(figsize=(8, 6))
    plt.hist(df[kolom], bins=20, edgecolor='black', density=True)

    skewness = df[kolom].skew()

    mean = df[kolom].mean()
    median = df[kolom].median()
    mode = df[kolom].mode()[0]

    std = df[kolom].std()

    plt.axvline(mean, color='red', linestyle='-', label='Mean')

    plt.axvline(median, color='orange', linestyle='-', label='Median')

    plt.axvline(mode, color='purple', linestyle='-', label='Modus')

    plt.axvline(mean + std, color='green', linestyle='--', label='Mean + 1 SD')

    plt.axvline(mean - std, color='green', linestyle='--')

    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    y = norm.pdf(x, mean, std)
    plt.plot(x, y, 'b-', label='Distribusi Normal')

    plt.title(f"Histogram Kolom {kolom} (Skewness: {skewness:.2f})")
    plt.xlabel(f"Nilai Kolom {kolom}")
    plt.ylabel("Density")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Menentukan Jenis Distribusi Data melalui Analisis Skewness-nya
#
#
# 1. Latitude:
#
# Jenis Distribusi: Mungkin mendekati Uniform, atau diskrit dengan sedikit skewness positif.
#
# Alasan: Nilai skewness 0.42 mendekati 0, yang menunjukkan distribusi mendekati simetris. Namun, histogram menunjukkan sedikit penyimpangan dari uniform, dengan sedikit kecenderungan ke arah kanan. Letak mean (27.9) sedikit lebih besar dari median (26.5) dan modus (9.5).
#
# 2. Longitude:
#
# Jenis Distribusi: Mungkin mendekati Uniform, atau diskrit dengan sedikit skewness positif.
#
# Alasan: Nilai skewness 1.05 mendekati 0, yang menunjukkan distribusi mendekati simetris. Namun, histogram menunjukkan sedikit penyimpangan dari uniform, dengan sedikit kecenderungan ke arah kanan. Letak mean (69.6) sedikit lebih besar dari median (65.5) dan modus (10.5).
#
# 3. OOSR_Pre0Primary_Age_Male:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 1.31 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (22.9) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 4. OOSR_Pre0Primary_Age_Female:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 1.34 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (19.5) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 5. OOSR_Primary_Age_Male:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 3.01 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (7.6) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 6. OOSR_Primary_Age_Female:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 3.08 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (5.1) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 7. OOSR_Lower_Secondary_Age_Male:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 1.88 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (11.7) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 8. OOSR_Lower_Secondary_Age_Female:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 2.20 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (18.8) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 9. OOSR_Upper_Secondary_Age_Male:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 0.98 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (23.6) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 10. OOSR_Upper_Secondary_Age_Female:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 1.23 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (22.6) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 11. Completion_Rate_Primary_Male:
#
# Jenis Distribusi: Mungkin mendekati Uniform, atau diskrit dengan sedikit skewness positif.
#
# Alasan: Nilai skewness 0.19 mendekati 0, yang menunjukkan distribusi mendekati simetris. Namun, histogram menunjukkan sedikit penyimpangan dari uniform, dengan sedikit kecenderungan ke arah kanan. Letak mean (42.9) sedikit lebih besar dari median (1) dan modus (0).
#
# 12. Completion_Rate_Primary_Female:
#
# Jenis Distribusi: Mungkin mendekati Uniform, atau diskrit dengan sedikit skewness positif.
#
# Alasan: Nilai skewness 0.21 mendekati 0, yang menunjukkan distribusi mendekati simetris. Namun, histogram menunjukkan sedikit penyimpangan dari uniform, dengan sedikit kecenderungan ke arah kanan. Letak mean (40.6) sedikit lebih besar dari median (1) dan modus (0).
#
# 13. Completion_Rate_Lower_Secondary_Male:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 0.58 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (42.8) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 14. Completion_Rate_Lower_Secondary_Female:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 0.61 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (40.8) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 15. Completion_Rate_Upper_Secondary_Male:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 1.09 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (34.3) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 16. Completion_Rate_Upper_Secondary_Female:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 1.11 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (33.7) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 17. Grade_2_3_Proficiency_Reading:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 1.23 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (29.5) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 18. Grade_2_3_Proficiency_Math:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 1.39 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (31.4) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 19. Primary_End_Proficiency_Reading:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 2.44 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (16.5) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 20. Primary_End_Proficiency_Math:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 2.09 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (16.6) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 21. Lower_Secondary_End_Proficiency_Reading:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 0.72 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (32.6) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 22. Lower_Secondary_End_Proficiency_Math:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 0.84 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (29.8) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 23. Youth_15_24_Literacy_Rate_Male:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 0.53 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (42.1) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 24. Youth_15_24_Literacy_Rate_Female:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 0.58 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (41.8) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 25. Birth_Rate:
#
# Jenis Distribusi: Mungkin mendekati Uniform, atau diskrit dengan sedikit skewness positif.
#
# Alasan: Nilai skewness 0.36 mendekati 0, yang menunjukkan distribusi mendekati simetris. Namun, histogram menunjukkan sedikit penyimpangan dari uniform, dengan sedikit kecenderungan ke arah kanan. Letak mean (22.8) sedikit lebih besar dari median (19.5) dan modus (10).
#
# 26. Gross_Primary_Education_Enrollment:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness -2.37 yang negatif konsisten dengan bentuk histogram, yang menunjukkan ekor kiri yang lebih panjang. Mean (95.7) lebih kecil dari median (100) dan modus (0), yang juga mengindikasikan skewness kiri.
#
# 27. Gross_Tertiary_Education_Enrollment:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 0.69 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (39.8) lebih besar dari median (1) dan modus (0), yang juga mengindikasikan skewness kanan.
#
# 28. Unemployment_Rate:
#
# Jenis Distribusi: Skewed Kanan (Right-skewed)
#
# Alasan: Nilai skewness 1.28 yang positif konsisten dengan bentuk histogram, yang menunjukkan ekor kanan yang lebih panjang. Mean (7.9) lebih besar dari median (4.5) dan modus (0), yang juga mengindikasikan skewness kanan.
